# %%
import pandas as pd

# %%
data = {
    "Name": ["Arman", "Rahul", "Sana"],
    "Marks": [85, 90, 88]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Marks
# 0  Arman     85
# 1  Rahul     90
# 2   Sana     88
